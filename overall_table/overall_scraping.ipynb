# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://loyolagreyhounds.com/sports/womens-basketball/stats/2022-23'
path='https://loyolagreyhounds.com'

data_list = []
columns_overall = []
dict_colspan = {}
index = 0

response = requests.get(url)
soup = BeautifulSoup(response.content,'html')
main = soup.find('main',class_='main-content-placeholder')
table_seasons = main.find('select',id='ctl00_cplhMainContent_seasons_ddl')
data_years = table_seasons.find_all('option',value=True)
years = [path+data['value'] for data in data_years[1:]]

for year in years:
    response = requests.get(year)
    soup = BeautifulSoup(response.content,'html')
    print(f'Successfully received {year}')
    date = year.split("stats/",1)[1]
    
    main = soup.find('main',class_='main-content-placeholder')
    overall = main.find('section',id='individual-overall')
    table = overall.find('table','sidearm-table')
    table_head = table.find('thead')
    headers_label = table_head.find_all('tr')[0]
    headers_column = table_head.find_all('tr')[1]

    body = table.find('tbody')
    players = body.find_all('tr')

    for player in players[:-1]:
        infos = player.find_all('td')
        data = [info.text.strip() for info in infos[:-1]]
        try:
            bio = infos[-1].find('a')['href']
            link= path+bio
        except TypeError:
            link=None
        data.extend([link,date])
        data_list.append(data)

for header in headers_label.find_all("th"):
    colspan_value = int(header.get("colspan", 1)) #if header dont have a colspan, colspan_value get 1 - 
    header_text = header.get_text()
    dict_colspan[header_text] = colspan_value
    
data_headers = headers_column.find_all('th')
for span,text in zip(dict_colspan.values(),dict_colspan.keys()):
    data = []
    if(span <= 1):
        columns_overall.append(text)
    else:
        data= [head.text.strip() + "_" + text for head in data_headers[index:index+span]]
        index += span
    columns_overall.extend(data)  # Yeni verileri ana liste içine ekler
       
df_overall = pd.DataFrame(data_list,columns = columns_overall+['date'])
# Out:
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2022-23
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2021-22
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2020-21
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2019-20
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2018-19
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2017-18
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2016-17
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2015-16
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2014-15
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2013-14
# Successfully received https://loyolagreyhounds.com/sports/womens-basketball/stats/2012-13

# %%
df_overall[33:]
# Out:
#       #                                             Player  GP GS TOT_Minutes  \
# 33   22                          Rozzi, Bri\n22 Rozzi, Bri  13  8         267
# 34   03  Tanedo, Caramina\r\n                          ...  13  3         215
# 35   02                  Edwards, Laryn\n02 Edwards, Laryn  12  5         244
# 36   10                    Sieper, Kayla\n10 Sieper, Kayla   4  0          25
# 37   12                  Steidle, Bella\n12 Steidle, Bella   6  0          24
# ..   ..                                                ...  .. ..         ...
# 148  22              Butler, Brittany\n22 Butler, Brittany   3  0           7
# 149  01  Robinson, Bryanna\r\n                         ...   6  0          25
# 150  42                      Perry, Jeneh\n42 Perry, Jeneh   5  0          17
# 151  35                          Brown, Nai\n35 Brown, Nai   6  1          19
# 152  25                      Smith, Julie\n25 Smith, Julie   2  0           2
#
#     AVG_Minutes FGM_FG FGA_FG FG%_FG 3PT_3PT  ... DEF_Rebounds TOT_Rebounds  \
# 33         20.5     14     45   .311       6  ...           25           29
# 34         16.5     11     37   .297       7  ...           14           15
# 35         20.3      8     33   .242       5  ...            9           12
# 36          6.3      2      4   .500       0  ...            2            3
# 37          4.0      1      4   .250       1  ...            3            3
# ..          ...    ...    ...    ...     ...  ...          ...          ...
# 148         2.3      1      3   .333       0  ...            0            0
# 149         4.2      0     10   .000       0  ...            1            4
# 150         3.4      0      3   .000       0  ...            2            3
# 151         3.2      0      2   .000       0  ...            3            3
# 152         1.0      0      0   .000       0  ...            1            1
#
#     AVG_Rebounds  PF AST  TO STL BLK  \
# 33           2.2  29  18  19   8   0
# 34           1.2   7  14   9   7   0
# 35           1.0  25  19  14  14   1
# 36           0.8   4   0   4   0   0
# 37           0.5   2   0   1   0   0
# ..           ...  ..  ..  ..  ..  ..
# 148          0.0   0   0   0   0   1
# 149          0.7   5   1   2   1   0
# 150          0.6   3   1   3   2   0
# 151          0.5   0   0   5   1   0
# 152          0.5   0   0   0   0   0
#
#                                               Bio Link     date
# 33   https://loyolagreyhounds.com/sports/womens-bas...  2020-21
# 34                                                None  2020-21
# 35   https://loyolagreyhounds.com/sports/womens-bas...  2020-21
# 36   https://loyolagreyhounds.com/sports/womens-bas...  2020-21
# 37   https://loyolagreyhounds.com/sports/womens-bas...  2020-21
# ..                                                 ...      ...
# 148  https://loyolagreyhounds.com/sports/womens-bas...  2012-13
# 149                                               None  2012-13
# 150  https://loyolagreyhounds.com/sports/womens-bas...  2012-13
# 151  https://loyolagreyhounds.com/sports/womens-bas...  2012-13
# 152  https://loyolagreyhounds.com/sports/womens-bas...  2012-13
#
# [120 rows x 28 columns]

# %%
def swap_ids(link1, link2):
    # Extract player IDs from the links
    id1_start = link1.rfind("=") + 1
    id1 = link1[id1_start:]
    
    id2_start = link2.rfind("/") + 1
    id2 = link2[id2_start:]
    
    # Create new links by swapping the IDs
    new_link = link2.replace(id2, id1)
    
    return new_link

# %%
def get_links(df_overall):
    links = []
    for bio_link,date in zip(df_overall['Bio Link'],df_overall['date']):
        
        try:
            r = requests.head(bio_link, allow_redirects=True)
            response = requests.get(bio_link)
            
            if(response.status_code==404 and r.url!=bio_link):
                bio_link = swap_ids(r.url, bio_link)
                print("new link - ",bio_link,"appended.")
            elif(response.status_code==404 and r.url==bio_link): #some players' pages are sending 404, and their page on redirected page
                bio_link = None
                print("Pages are sending 404\t None values appended.")
            links.append([bio_link,date])
                
        except requests.exceptions.MissingSchema:
            print('MissingSchema error\t None values appended.')
            links.append([None,date])
    return links

# %%
links = get_links(df_overall)
print("\nPlayers' pages have been edited and data is ready to be pulled.")
# Out:
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/koi-sims/12239 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/kelly-ratigan/12237 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/meliah-van-otoo/12243 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/cristina-garcia/12234 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/marta-espinal/12233 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/caroline-orza/12236 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/charia-roberts/10966 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620 appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bella-steidle/10969 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241 appended.
# Pages are sending 404	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/claire-jakaitis/3671 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/tori-schultz/3696 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/colleen-marshall/3701 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714 appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712 appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698 appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973 appended.
# MissingSchema error	 None values appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/nicole-krusen/3735 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/nneka-offodile/3733 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/tiffany-padgett/3728 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/brittany-butler/3731 appended.
# MissingSchema error	 None values appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714 appended.
# new link -  https://loyolagreyhounds.com/sports/womens-basketball/roster/nai-brown/3736 appended.
#
# Players' pages have been edited and data is ready to be pulled.

# %%
"""

def get_non_historical_detail(soup,ind):
    fields = soup.find('div',class_='sidearm-roster-player-fields')
    details = fields.find_all('li',class_='large-6')
    detail_temp = [detail.find('dd').text for detail in details[ind:]]
    return detail_temp

"""

# %%
detail_header = None
detail_players=[]

for ind,link in enumerate(links):
    detail_player=[]
    
    if link[0] is None :
        print("None value encountered. Skipping...")
        detail_player = [None for i in range(len(details))]
        detail_players.append(detail_player)
        continue
    
    response = requests.get(link[0])
    soup = BeautifulSoup(response.content,'html')
    
        
    fields = soup.find('div',class_='sidearm-roster-player-fields')
    details = fields.find_all('li',class_='large-6') #player nonhistorical info table
    
    #detail by year of the data
    historical = soup.find('ul',class_='sidearm-list-card-template-1')
    try:
        cards = historical.find_all('li','sidearm-list-card-item')
        print(link,'is running.')
        for card in cards:
            info_year = card.find('span',class_='sidearm-roster-player-first-name').text
            if info_year == link[1]:
                
                info_class = card.find('span',class_='sidearm-roster-player-last-name').text
                info_pos = card.find('div',class_='sidearm-list-card-details-item').text
                  
                info_height_inc= card.find('span',class_='sidearm-roster-player-height').text.strip()#.rsplit()[0]
                #print(info_height_inc)
                #info_height_num = "".join([info_height_inc[0],'-',info_height_inc[2]])

                detail_player.extend([info_pos,info_height_inc,info_class])
                
                ind = -3 if len(details) > 5 else -2   #general detail

    except AttributeError:
        ind=0    #general detail


    detail_temp = [detail.find('dd').text for detail in details[ind:]] #player non historical info values
    detail_player.extend(detail_temp)
    print(detail_player)
    detail_players.append(detail_player)
      
    if detail_header is None and len(detail_player)>5: #because have max 6 information of player 
        detail_header = [detail.find('dt').text for detail in details] #player non historical info keys(column names)
        
    print(link[0]," is done.\n")
# Out:
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242', '2022-23'] is running.
# ['Forward', '6\'1"', 'Sophomore', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617', '2022-23'] is running.
# ['Guard', '5\'10"', 'Graduate Student', 'McDonogh School', 'Baltimore, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619', '2022-23'] is running.
# ['Guard', '5\'8"', 'Graduate Student', 'Herndon', 'Herndon, Va.', "St. Joseph's"]
# https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/koi-sims/12239', '2022-23'] is running.
# ['Forward', '6\'0"', 'Sophomore', 'Archbishop Spalding', 'Glen Burnie, Md.', 'Albany']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/koi-sims/12239  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620', '2022-23'] is running.
# ['Guard', '5\'7"', 'Senior', 'Highland', 'Highland, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/kelly-ratigan/12237', '2022-23'] is running.
# ['Guard', '5\'8"', 'Freshman', 'Saint Joseph', 'South Bend, Ind.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/kelly-ratigan/12237  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240', '2022-23'] is running.
# ['Guard', '5\'10"', 'Junior', "St. John's College", 'Laurel, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/meliah-van-otoo/12243', '2022-23'] is running.
# ['Guard', '5\'4"', 'Freshman', 'Westtown School', 'Drexel Hill, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/meliah-van-otoo/12243  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238', '2022-23'] is running.
# ['Guard', '5\'8"', 'Sophomore', 'Institut Llavaneres', 'Sant Andreu de Llavaneres, Spain']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/cristina-garcia/12234', '2022-23'] is running.
# ['Guard', '5\'9"', 'Freshman', 'Pisgah', 'Sant Cugat del Vallés, Spain']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/cristina-garcia/12234  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/marta-espinal/12233', '2022-23'] is running.
# ['Forward', '5\'11"', 'Freshman', "Les d'Auro School", 'Castellnou de Bages, Spain']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/marta-espinal/12233  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618', '2022-23'] is running.
# ['Forward', '6\'1"', 'Senior', 'Long Island Lutheran', 'Wantagh, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241', '2022-23'] is running.
# ['Forward', '5\'10"', 'Senior', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/caroline-orza/12236', '2022-23'] is running.
# ['Guard', '5\'9"', 'Freshman', 'Bethesda Chevy Chase', 'Chevy Chase, MD']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/caroline-orza/12236  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242', '2021-22'] is running.
# ['Forward', '6\'1"', 'Freshman', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lex-therien/12242  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617', '2021-22'] is running.
# ['Guard', '5\'10"', 'Senior', 'McDonogh School', 'Baltimore, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238', '2021-22'] is running.
# ['Guard', '5\'8"', 'Freshman', 'Institut Llavaneres', 'Sant Andreu de Llavaneres, Spain']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laura-salmer-oacute-n/12238  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620', '2021-22'] is running.
# ['Guard', '5\'7"', 'Junior', 'Highland', 'Highland, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/charia-roberts/10966', '2021-22'] is running.
# ['Forward', '6\'0"', 'Sophomore', 'Pikesville', 'Pikesville, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/charia-roberts/10966  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619', '2021-22'] is running.
# ['Guard', '5\'8"', 'Senior', 'Herndon', 'Herndon, Va.', "St. Joseph's"]
# https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240', '2021-22'] is running.
# ['Guard', '5\'10"', 'Sophomore', "St. John's College", 'Laurel, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/caramina-ta-ntilde-edo/12240  is done.
#
# ['Guard', '5-7', 'Freshman', 'Haddonfield Memorial', 'Haddonfield, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/keegan-douglas/10974  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962', '2021-22'] is running.
# ['Guard', '5\'6"', 'Senior', 'Hampton', 'Allison Park, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964', '2021-22'] is running.
# ['Forward', '6\'0"', 'Junior', 'Garnet Valley', 'Thornton, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618', '2021-22'] is running.
# ['Forward', '6\'1"', 'Junior', 'Long Island Lutheran', 'Wantagh, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bella-steidle/10969', '2021-22'] is running.
# ['Guard', '5\'11"', 'Sophomore', 'Clearview Regional', 'Mullica Hill, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bella-steidle/10969  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241', '2021-22'] is running.
# ['Forward', '5\'10"', 'Junior', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613', '2020-21'] is running.
# ['Forward', '6\'1"', 'Senior', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964', '2020-21'] is running.
# ['Forward', '6\'0"', 'Sophomore', 'Garnet Valley', 'Thornton, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617', '2020-21'] is running.
# ['Guard', '5\'10"', 'Junior', 'McDonogh School', 'Baltimore, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619', '2020-21'] is running.
# ['Guard', '5\'8"', 'Junior', 'Herndon', 'Herndon, Va.', "St. Joseph's"]
# https://loyolagreyhounds.com/sports/womens-basketball/roster/devyne-newman/11619  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606', '2020-21'] is running.
# ['Forward', '6\'0"', 'Senior', 'Oakton', 'Vienna, Va.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/charia-roberts/10966', '2020-21'] is running.
# ['Forward', '6\'0"', 'Freshman', 'Pikesville', 'Pikesville, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/charia-roberts/10966  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620', '2020-21'] is running.
# ['Guard', '5\'7"', 'Sophomore', 'Highland', 'Highland, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962', '2020-21'] is running.
# ['Guard', '5\'6"', 'Junior', 'Hampton', 'Allison Park, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962  is done.
#
# ['Forward', '6-1', 'Freshman', 'H.B. Plant', 'Tampa, Fla.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/kayla-sieper/8616  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bella-steidle/10969', '2020-21'] is running.
# ['Guard', '5\'10"', 'Freshman', 'Clearview Regional', 'Mullica Hill, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bella-steidle/10969  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618', '2020-21'] is running.
# ['Forward', '6\'1"', 'Sophomore', 'Long Island Lutheran', 'Wantagh, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086', '2019-20'] is running.
# ['Guard', '5\'11"', 'Senior', 'Middletown South', 'Middletown, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084', '2019-20'] is running.
# ['Guard', '5\'6"', 'Senior', 'Georgetown Visitation', 'Clarksburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613', '2019-20'] is running.
# ['Forward', '6\'1"', 'Junior', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962', '2019-20'] is running.
# ['Guard', '5\'6"', 'Sophomore', 'Hampton', 'Allison Park, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606', '2019-20'] is running.
# ['Forward', '6\'0"', 'Junior', 'Oakton', 'Vienna, Va.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964', '2019-20'] is running.
# ['Forward', '6\'0"', 'Freshman', 'Garnet Valley', 'Thornton, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emily-mcateer/10964  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087', '2019-20'] is running.
# ['Guard', '5\'9"', 'Senior', 'Walt Whitman', 'Glen Echo, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620', '2019-20'] is running.
# ['Guard', '5\'7"', 'Freshman', 'Highland', 'Highland, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-rozzi/11620  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241', '2019-20'] is running.
# ['Guard', '5\'10"', 'Freshman', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ava-therien/12241  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085', '2019-20'] is running.
# ['Forward', '6\'0"', 'Graduate Student', 'The John Carroll School', 'Abingdon, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618', '2019-20'] is running.
# ['Forward', '6\'1"', 'Freshman', 'Long Island Lutheran', 'Wantagh, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/emma-glezen/11618  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088', '2019-20'] is running.
# ['Guard', '5\'9"', 'Senior', 'Mercersburg Academy', 'Cranleigh, England']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613', '2018-19'] is running.
# ['Forward', '6\'"', 'Sophomore', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617', '2018-19'] is running.
# ['Guard/Forward', '5\'10"', 'Freshman', 'McDonogh School', 'Baltimore, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/taleah-dixon/11617  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606', '2018-19'] is running.
# ['Forward', '6\'"', 'Sophomore', 'Oakton', 'Vienna, Va.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319', '2018-19'] is running.
# ['Guard', '5\'3"', 'Fifth Year', 'Trinity', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084', '2018-19'] is running.
# ['Guard', '5\'6"', 'Junior', 'Georgetown Visitation', 'Clarksburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086', '2018-19'] is running.
# ['Guard', '5\'11"', 'Junior', 'Middletown South', 'Middletown, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087', '2018-19'] is running.
# ['Guard', '5\'9"', 'Junior', 'Walt Whitman', 'Glen Echo, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315', '2018-19'] is running.
# ['Guard', '5\'11"', 'Senior', 'Saucon Valley', 'Bethlehem, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085', '2018-19'] is running.
# ['Forward', '6\'"', 'Senior', 'The John Carroll School', 'Abingdon, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088', '2018-19'] is running.
# ['Guard', '5\'9"', 'Junior', 'Mercersburg Academy', 'Cranleigh, England']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324', '2018-19'] is running.
# ['Guard', '5\'6"', 'Senior', 'Red Bank Catholic', 'Howell, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327', '2018-19'] is running.
# ['Forward', '6\'1"', 'Senior', 'Blackhawk', 'Beaver Falls, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962', '2018-19'] is running.
# ['Guard', '5\'6"', 'Freshman', 'Hampton', 'Allison Park, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/laryn-edwards/10962  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613', '2017-18'] is running.
# ['Forward', '6\'"', 'Freshman', 'Cherokee', 'Marlton, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/isabella-therien/8613  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086', '2017-18'] is running.
# ['Guard', '5\'11"', 'Sophomore', 'Middletown South', 'Middletown, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084', '2017-18'] is running.
# ['Guard', '5\'6"', 'Sophomore', 'Georgetown Visitation', 'Clarksburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319', '2017-18'] is running.
# ['Guard', '5\'3"', 'Senior', 'Trinity', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085', '2017-18'] is running.
# ['Forward', '6\'"', 'Junior', 'The John Carroll School', 'Abingdon, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606', '2017-18'] is running.
# ['Forward', '6\'"', 'Freshman', 'Oakton', 'Vienna, Va.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/delaney-connolly/8606  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974', '2017-18'] is running.
# ['Guard', '5\'8"', 'Senior', 'Central Dauphin East', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088', '2017-18'] is running.
# ['Guard', '5\'9"', 'Sophomore', 'Mercersburg Academy', 'Cranleigh, England']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327', '2017-18'] is running.
# ['Forward', '6\'1"', 'Junior', 'Blackhawk', 'Beaver Falls, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973', '2017-18'] is running.
# ['Guard', '5\'10"', 'Senior', 'Southern Lehigh', 'Coopersburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087', '2017-18'] is running.
# ['Guard', '5\'9"', 'Sophomore', 'Walt Whitman', 'Glen Echo, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315', '2017-18'] is running.
# ['Guard', '5\'11"', 'Junior', 'Saucon Valley', 'Bethlehem, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/claire-jakaitis/3671', '2017-18'] is running.
# ['Forward', '6\'2"', 'Sophomore', 'St. Charles North', 'South Elgin, Ill.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/claire-jakaitis/3671  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972', '2017-18'] is running.
# ['Guard/Forward', '', 'Junior', 'The Episcopal Acadmey', 'Berwyn, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324', '2017-18'] is running.
# ['Guard', '5\'6"', 'Junior', 'Red Bank Catholic', 'Howell, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319', '2016-17'] is running.
# ['Guard', '5\'3"', 'Junior', 'Trinity', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692', '2016-17'] is running.
# ['Forward', '6\'"', 'Senior', 'Hanover Park', 'Florham Park, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086', '2016-17'] is running.
# ['Guard', '5\'11"', 'Freshman', 'Middletown South', 'Middletown, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/stephanie-karcz/8086  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084', '2016-17'] is running.
# ['Guard', '5\'6"', 'Freshman', 'Georgetown Visitation', 'Clarksburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alexis-gray/8084  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694', '2016-17'] is running.
# ['Guard', '5\'8"', 'Senior', 'Villa Maria Academy', 'West Chester, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088', '2016-17'] is running.
# ['Guard', '5\'9"', 'Freshman', 'Mercersburg Academy', 'Cranleigh, England']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/molly-taylor/8088  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698', '2016-17'] is running.
# ['Guard/Forward', '5\'10"', 'Junior', 'Mount St. Joseph Academy', 'Flourtown, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324', '2016-17'] is running.
# ['Guard', '5\'6"', 'Sophomore', 'Red Bank Catholic', 'Howell, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085', '2016-17'] is running.
# ['Forward', '6\'"', 'Sophomore', 'The John Carroll School', 'Abingdon, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327', '2016-17'] is running.
# ['Forward', '6\'1"', 'Sophomore', 'Blackhawk', 'Beaver Falls, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315', '2016-17'] is running.
# ['Guard', '5\'11"', 'Sophomore', 'Saucon Valley', 'Bethlehem, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973', '2016-17'] is running.
# ['Guard', '5\'10"', 'Junior', 'Southern Lehigh', 'Coopersburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972', '2016-17'] is running.
# ['Guard/Forward', '5\'9"', 'Sophomore', 'The Episcopal Acadmey', 'Berwyn, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/tori-schultz/3696', '2016-17'] is running.
# ['Forward', '6\'"', 'Sophomore', 'Lampeter-Strasburg', 'Lancaster, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/tori-schultz/3696  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974', '2016-17'] is running.
# ['Guard', '5\'8"', 'Junior', 'Central Dauphin East', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087', '2016-17'] is running.
# ['Guard', '5\'9"', 'Freshman', 'Walt Whitman', 'Glen Echo, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/hannah-niles/8087  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/claire-jakaitis/3671', '2016-17'] is running.
# ['Forward', '6\'2"', 'Freshman', 'St. Charles North', 'South Elgin, Ill.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/claire-jakaitis/3671  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/colleen-marshall/3701', '2015-16'] is running.
# ['Guard', '5\'9"', 'Senior', 'Gaithersburg', 'Gaithersburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/colleen-marshall/3701  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319', '2015-16'] is running.
# ['Guard', '5\'3"', 'Sophomore', 'Trinity', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714', '2015-16'] is running.
# ['Forward', '6\'"', 'Senior', 'Girls Preparatory School', 'Chattanooga, Tenn.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712', '2015-16'] is running.
# ['Forward', '6\'"', 'Fifth Year', 'Mount St. Joseph Academy', 'Lower Gwynedd, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706', '2015-16'] is running.
# ['Guard', '5\'11"', 'Senior', 'North Point', 'Waldorf, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694', '2015-16'] is running.
# ['Guard', '5\'8"', 'Junior', 'Villa Maria Academy', 'West Chester, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974', '2015-16'] is running.
# ['Guard', '5\'8"', 'Sophomore', 'Central Dauphin East', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/calee-gelbaugh/6974  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692', '2015-16'] is running.
# ['Forward', '6\'"', 'Junior', 'Hanover Park', 'Florham Park, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327', '2015-16'] is running.
# ['Forward', '6\'1"', 'Freshman', 'Blackhawk', 'Beaver Falls, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/courtney-vannoy/6327  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973', '2015-16'] is running.
# ['Guard', '5\'10"', 'Sophomore', 'Southern Lehigh', 'Coopersburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324', '2015-16'] is running.
# ['Guard', '5\'6"', 'Freshman', 'Red Bank Catholic', 'Howell, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alex-barazotti/6324  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085', '2015-16'] is running.
# ['Forward', '6\'"', 'Freshman', 'The John Carroll School', 'Abingdon, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/ashley-hunter/8085  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315', '2015-16'] is running.
# ['Guard', '5\'11"', 'Freshman', 'Saucon Valley', 'Bethlehem, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/abby-omdahl/6315  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698', '2015-16'] is running.
# ['Guard/Forward', '5\'10"', 'Sophomore', 'Mount St. Joseph Academy', 'Flourtown, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972', '2015-16'] is running.
# ['Guard/Forward', '5\'9"', 'Freshman', 'The Episcopal Acadmey', 'Berwyn, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/maria-kilcullen/6972  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/tori-schultz/3696', '2015-16'] is running.
# ['Forward', '6\'"', 'Freshman', 'Lampeter-Strasburg', 'Lancaster, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/tori-schultz/3696  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/colleen-marshall/3701', '2014-15'] is running.
# ['Guard', '5\'9"', 'Junior', 'Gaithersburg', 'Gaithersburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/colleen-marshall/3701  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319', '2014-15'] is running.
# ['Guard', '5\'3"', 'Freshman', 'Trinity', 'Harrisburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/bri-betz-white/6319  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714', '2014-15'] is running.
# ['Forward', '5\'11"', 'Junior', 'Girls Preparatory School', 'Chattanooga, Tenn.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706', '2014-15'] is running.
# ['Guard', '5\'11"', 'Junior', 'North Point', 'Waldorf, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694', '2014-15'] is running.
# ['Guard', '5\'8"', 'Sophomore', 'Villa Maria Academy', 'West Chester, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692', '2014-15'] is running.
# ['Forward', '6\'"', 'Sophomore', 'Hanover Park', 'Florham Park, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716', '2014-15'] is running.
# ['Guard', '5\'8"', 'Senior', 'Gaithersburg', 'Gaithersburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712', '2014-15'] is running.
# ['Forward', '6\'"', 'Senior', 'Mount St. Joseph Academy', 'Lower Gwynedd, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698', '2014-15'] is running.
# ['Guard/Forward', '5\'10"', 'Freshman', 'Mount St. Joseph Academy', 'Flourtown, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/carly-monzo/3698  is done.
#
# ['Forward', '5-10', 'Sophomore', 'Hononegah', 'Rockton, Ill.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/karley-kolberg/3723  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973', '2014-15'] is running.
# ['Guard', '5\'10"', 'Freshman', 'Southern Lehigh', 'Coopersburg, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/madelene-mcdonald/6973  is done.
#
# None value encountered. Skipping...
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nai-brown/3736', '2013-14'] is running.
# ['Guard', '5\'9"', 'Junior', 'Sanford School', 'Newark, Del.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nai-brown/3736  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716', '2013-14'] is running.
# ['Guard', '5\'8"', 'Junior', 'Gaithersburg', 'Gaithersburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694', '2013-14'] is running.
# ['Guard', '5\'8"', 'Freshman', 'Villa Maria Academy', 'West Chester, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lisa-mirarchi/3694  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nicole-krusen/3735', '2013-14'] is running.
# ['Guard', '6\'"', 'Senior', 'Georgetown Visitation', 'Rockville, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nicole-krusen/3735  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/tiffany-padgett/3728', '2013-14'] is running.
# ['Center', '6\'1"', 'Sophomore', 'St. Vincent Pallotti', 'Laurel, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/tiffany-padgett/3728  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nneka-offodile/3733', '2013-14'] is running.
# ['Forward', '6\'1"', 'Senior', 'Walsh Jesuit', 'Kent, Ohio']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nneka-offodile/3733  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714', '2013-14'] is running.
# ['Forward', '5\'11"', 'Sophomore', 'Girls Preparatory School', 'Chattanooga, Tenn.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706', '2013-14'] is running.
# ['Guard', '5\'11"', 'Sophomore', 'North Point', 'Waldorf, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692', '2013-14'] is running.
# ['Forward', '6\'"', 'Freshman', 'Hanover Park', 'Florham Park, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/lauren-daugherty/3692  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/brittany-butler/3731', '2013-14'] is running.
# ['Guard', '5\'9"', 'Sophomore', 'Howard', 'Elkridge, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/brittany-butler/3731  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/katie-sheahin/3741', '2012-13'] is running.
# ['Guard', '5\'10"', 'Senior', 'Our Lady of Good Counsel', 'Brookeville, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/katie-sheahin/3741  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716', '2012-13'] is running.
# ['Guard', '5\'8"', 'Sophomore', 'Gaithersburg', 'Gaithersburg, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/kara-marshall/3716  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/alyssa-sutherland/3745', '2012-13'] is running.
# ['Forward', '6\'1"', 'Senior', 'West Genesee', 'Syracuse, N.Y.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/alyssa-sutherland/3745  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nicole-krusen/3735', '2012-13'] is running.
# ['Guard', '6\'"', 'Junior', 'Georgetown Visitation', 'Rockville, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nicole-krusen/3735  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nneka-offodile/3733', '2012-13'] is running.
# ['Forward', '6\'1"', 'Junior', 'Walsh Jesuit', 'Kent, Ohio']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nneka-offodile/3733  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706', '2012-13'] is running.
# ['Guard', '5\'11"', 'Freshman', 'North Point', 'Waldorf, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/diana-logan/3706  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/candice-walker/3743', '2012-13'] is running.
# ['Guard', '5\'5"', 'Fifth Year', 'Towson Catholic', 'Baltimore, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/candice-walker/3743  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/tiffany-padgett/3728', '2012-13'] is running.
# ['Center', '6\'1"', 'Freshman', 'St. Vincent Pallotti', 'Laurel, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/tiffany-padgett/3728  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712', '2012-13'] is running.
# ['Forward', '6\'"', 'Sophomore', 'Mount St. Joseph Academy', 'Lower Gwynedd, Pa.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/steph-smith/3712  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/brittany-butler/3731', '2012-13'] is running.
# ['Guard', '5\'9"', 'Freshman', 'Howard', 'Elkridge, Md.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/brittany-butler/3731  is done.
#
# None value encountered. Skipping...
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714', '2012-13'] is running.
# ['Forward', '5\'11"', 'Freshman', 'Girls Preparatory School', 'Chattanooga, Tenn.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/jeneh-perry/3714  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/nai-brown/3736', '2012-13'] is running.
# ['Guard', '5\'9"', 'Sophomore', 'Sanford School', 'Newark, Del.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/nai-brown/3736  is done.
#
# ['https://loyolagreyhounds.com/sports/womens-basketball/roster/julie-smith/3744', '2012-13'] is running.
# ['Guard', '5\'7"', 'Junior', 'Montgomery', 'Skillman, N.J.']
# https://loyolagreyhounds.com/sports/womens-basketball/roster/julie-smith/3744  is done.

# %%
print(detail_header)
# Out:
# ['Position', 'Height', 'Class', 'Highschool', 'Hometown', 'Prev School']

# %%
df_overall_final = pd.concat([df_overall,pd.DataFrame(detail_players,columns=detail_header)],axis=1)
df_overall_final
# Out:
#       #                                             Player  GP  GS  \
# 0    45                      Therien, Lex\n45 Therien, Lex  31  31
# 1    04                    Dixon, Taleah\n04 Dixon, Taleah  30  30
# 2    05                  Newman, Devyne\n05 Newman, Devyne  20  13
# 3    10                            Sims, Koi\n10 Sims, Koi  20  19
# 4    22                          Rozzi, Bri\n22 Rozzi, Bri  27  23
# ..   ..                                                ...  ..  ..
# 148  22              Butler, Brittany\n22 Butler, Brittany   3   0
# 149  01  Robinson, Bryanna\r\n                         ...   6   0
# 150  42                      Perry, Jeneh\n42 Perry, Jeneh   5   0
# 151  35                          Brown, Nai\n35 Brown, Nai   6   1
# 152  25                      Smith, Julie\n25 Smith, Julie   2   0
#
#     TOT_Minutes AVG_Minutes FGM_FG FGA_FG FG%_FG 3PT_3PT  ... STL BLK  \
# 0           965        31.1    187    381   .491       2  ...  49   7
# 1           969        32.3    138    395   .349      44  ...  44   1
# 2           497        24.9     67    170   .394       8  ...   6   0
# 3           536        26.8     58    132   .439       0  ...  17  18
# 4           746        27.6     55    155   .355      20  ...  16   0
# ..          ...         ...    ...    ...    ...     ...  ...  ..  ..
# 148           7         2.3      1      3   .333       0  ...   0   1
# 149          25         4.2      0     10   .000       0  ...   1   0
# 150          17         3.4      0      3   .000       0  ...   2   0
# 151          19         3.2      0      2   .000       0  ...   1   0
# 152           2         1.0      0      0   .000       0  ...   0   0
#
#                                               Bio Link     date Position  \
# 0    https://loyolagreyhounds.com/sports/womens-bas...  2022-23  Forward
# 1    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# 2    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# 3    https://loyolagreyhounds.com/sports/womens-bas...  2022-23  Forward
# 4    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# ..                                                 ...      ...      ...
# 148  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
# 149                                               None  2012-13     None
# 150  https://loyolagreyhounds.com/sports/womens-bas...  2012-13  Forward
# 151  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
# 152  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
#
#     Height             Class                Highschool            Hometown  \
# 0     6'1"         Sophomore                  Cherokee       Marlton, N.J.
# 1    5'10"  Graduate Student           McDonogh School      Baltimore, Md.
# 2     5'8"  Graduate Student                   Herndon        Herndon, Va.
# 3     6'0"         Sophomore       Archbishop Spalding    Glen Burnie, Md.
# 4     5'7"            Senior                  Highland      Highland, N.Y.
# ..     ...               ...                       ...                 ...
# 148   5'9"          Freshman                    Howard       Elkridge, Md.
# 149   None              None                      None                None
# 150  5'11"          Freshman  Girls Preparatory School  Chattanooga, Tenn.
# 151   5'9"         Sophomore            Sanford School        Newark, Del.
# 152   5'7"            Junior                Montgomery      Skillman, N.J.
#
#       Prev School
# 0            None
# 1            None
# 2    St. Joseph's
# 3          Albany
# 4            None
# ..            ...
# 148          None
# 149          None
# 150          None
# 151          None
# 152          None
#
# [153 rows x 34 columns]

# %%
df_overall_final['Player'] = df_overall_final['Player'].apply(lambda x: x.split("\n")[0].strip())
df_overall_final
# Out:
#       #             Player  GP  GS TOT_Minutes AVG_Minutes FGM_FG FGA_FG  \
# 0    45       Therien, Lex  31  31         965        31.1    187    381
# 1    04      Dixon, Taleah  30  30         969        32.3    138    395
# 2    05     Newman, Devyne  20  13         497        24.9     67    170
# 3    10          Sims, Koi  20  19         536        26.8     58    132
# 4    22         Rozzi, Bri  27  23         746        27.6     55    155
# ..   ..                ...  ..  ..         ...         ...    ...    ...
# 148  22   Butler, Brittany   3   0           7         2.3      1      3
# 149  01  Robinson, Bryanna   6   0          25         4.2      0     10
# 150  42       Perry, Jeneh   5   0          17         3.4      0      3
# 151  35         Brown, Nai   6   1          19         3.2      0      2
# 152  25       Smith, Julie   2   0           2         1.0      0      0
#
#     FG%_FG 3PT_3PT  ... STL BLK  \
# 0     .491       2  ...  49   7
# 1     .349      44  ...  44   1
# 2     .394       8  ...   6   0
# 3     .439       0  ...  17  18
# 4     .355      20  ...  16   0
# ..     ...     ...  ...  ..  ..
# 148   .333       0  ...   0   1
# 149   .000       0  ...   1   0
# 150   .000       0  ...   2   0
# 151   .000       0  ...   1   0
# 152   .000       0  ...   0   0
#
#                                               Bio Link     date Position  \
# 0    https://loyolagreyhounds.com/sports/womens-bas...  2022-23  Forward
# 1    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# 2    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# 3    https://loyolagreyhounds.com/sports/womens-bas...  2022-23  Forward
# 4    https://loyolagreyhounds.com/sports/womens-bas...  2022-23    Guard
# ..                                                 ...      ...      ...
# 148  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
# 149                                               None  2012-13     None
# 150  https://loyolagreyhounds.com/sports/womens-bas...  2012-13  Forward
# 151  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
# 152  https://loyolagreyhounds.com/sports/womens-bas...  2012-13    Guard
#
#     Height             Class                Highschool            Hometown  \
# 0     6'1"         Sophomore                  Cherokee       Marlton, N.J.
# 1    5'10"  Graduate Student           McDonogh School      Baltimore, Md.
# 2     5'8"  Graduate Student                   Herndon        Herndon, Va.
# 3     6'0"         Sophomore       Archbishop Spalding    Glen Burnie, Md.
# 4     5'7"            Senior                  Highland      Highland, N.Y.
# ..     ...               ...                       ...                 ...
# 148   5'9"          Freshman                    Howard       Elkridge, Md.
# 149   None              None                      None                None
# 150  5'11"          Freshman  Girls Preparatory School  Chattanooga, Tenn.
# 151   5'9"         Sophomore            Sanford School        Newark, Del.
# 152   5'7"            Junior                Montgomery      Skillman, N.J.
#
#       Prev School
# 0            None
# 1            None
# 2    St. Joseph's
# 3          Albany
# 4            None
# ..            ...
# 148          None
# 149          None
# 150          None
# 151          None
# 152          None
#
# [153 rows x 34 columns]

# %%
df_overall_final[df_overall_final['Player']=='Dixon, Taleah']
# Out:
#      #         Player  GP  GS TOT_Minutes AVG_Minutes FGM_FG FGA_FG FG%_FG  \
# 1   04  Dixon, Taleah  30  30         969        32.3    138    395   .349
# 15  04  Dixon, Taleah  29  29         879        30.3    102    312   .327
# 29  04  Dixon, Taleah  13  13         410        31.5     34    136   .250
# 53  04  Dixon, Taleah  28  16         727        26.0     91    266   .342
#
#    3PT_3PT  ... STL BLK                                           Bio Link  \
# 1       44  ...  44   1  https://loyolagreyhounds.com/sports/womens-bas...
# 15      38  ...  36   3  https://loyolagreyhounds.com/sports/womens-bas...
# 29       8  ...  12   1  https://loyolagreyhounds.com/sports/womens-bas...
# 53      20  ...  29   6  https://loyolagreyhounds.com/sports/womens-bas...
#
#        date       Position Height             Class       Highschool  \
# 1   2022-23          Guard  5'10"  Graduate Student  McDonogh School
# 15  2021-22          Guard  5'10"            Senior  McDonogh School
# 29  2020-21          Guard  5'10"            Junior  McDonogh School
# 53  2018-19  Guard/Forward  5'10"          Freshman  McDonogh School
#
#           Hometown Prev School
# 1   Baltimore, Md.        None
# 15  Baltimore, Md.        None
# 29  Baltimore, Md.        None
# 53  Baltimore, Md.        None
#
# [4 rows x 34 columns]

# %%
df_overall_final.to_csv('df_overall_final.csv',index=False)

# %%
df.head(1)
# Out:
#     #        Player  GP  GS  TOT_Minutes  AVG_Minutes  FGM_FG  FGA_FG  FG%_FG  \
# 0  45  Therien, Lex  31  31          965         31.1     187     381   0.491
#
#    3PT_3PT  ...  STL  BLK                                           Bio Link  \
# 0        2  ...   49    7  https://loyolagreyhounds.com/sports/womens-bas...
#
#       date  Position  Height      Class  Highschool       Hometown  \
# 0  2022-23   Forward    6'1"  Sophomore    Cherokee  Marlton, N.J.
#
#    Prev School
# 0          NaN
#
# [1 rows x 34 columns]

# %%
df = pd.read_csv('df_overall_final.csv')
df[df['Player']=='Dixon, Taleah']
# Out:
#      #         Player  GP  GS  TOT_Minutes  AVG_Minutes  FGM_FG  FGA_FG  \
# 1   04  Dixon, Taleah  30  30          969         32.3     138     395
# 15  04  Dixon, Taleah  29  29          879         30.3     102     312
# 29  04  Dixon, Taleah  13  13          410         31.5      34     136
# 53  04  Dixon, Taleah  28  16          727         26.0      91     266
#
#     FG%_FG  3PT_3PT  ...  STL  BLK  \
# 1    0.349       44  ...   44    1
# 15   0.327       38  ...   36    3
# 29   0.250        8  ...   12    1
# 53   0.342       20  ...   29    6
#
#                                              Bio Link     date       Position  \
# 1   https://loyolagreyhounds.com/sports/womens-bas...  2022-23          Guard
# 15  https://loyolagreyhounds.com/sports/womens-bas...  2021-22          Guard
# 29  https://loyolagreyhounds.com/sports/womens-bas...  2020-21          Guard
# 53  https://loyolagreyhounds.com/sports/womens-bas...  2018-19  Guard/Forward
#
#     Height             Class       Highschool        Hometown  Prev School
# 1    5'10"  Graduate Student  McDonogh School  Baltimore, Md.          NaN
# 15   5'10"            Senior  McDonogh School  Baltimore, Md.          NaN
# 29   5'10"            Junior  McDonogh School  Baltimore, Md.          NaN
# 53   5'10"          Freshman  McDonogh School  Baltimore, Md.          NaN
#
# [4 rows x 34 columns]
